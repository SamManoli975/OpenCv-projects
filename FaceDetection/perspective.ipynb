# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('testmedia/tennis.jpg')
assert img is not None, "file could not be read, check with os.path.exists()"
rows,cols,ch = img.shape
 
pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])
 
M = cv.getAffineTransform(pts1,pts2)
 
dst = cv.warpAffine(img,M,(cols,rows))
 
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv.imread('testmedia/tennis.jpg')
assert img is not None, "file could not be read, check with os.path.exists()"
rows,cols,ch = img.shape
 
pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
 
M = cv.getPerspectiveTransform(pts1,pts2)
 
dst = cv.warpPerspective(img,M,(300,300))
 
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
import cv2
from operator import itemgetter
from glob import glob
import matplotlib.pyplot as plt
paper = cv2.imread('testmedia/tennis.jpg')
# Coordinates that you want to Perspective Transform
pts1 = np.float32([[400,900],[550,1300],[700,150],[1000,750]])
# Size of the Transformed Image
pts2 = np.float32([[0,0],[500,0],[0,400],[500,400]])
for val in pt1:
    cv2.circle(paper,(val[0],val[1]),5,(0,255,0),-1)
M = cv2.getPerspectiveTransform(pt1,pts2)
dst = cv2.warpPerspective(paper,M,(500,400))
plt.imshow(dst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       8 # Size of the Transformed Image
#       9 pts2 = np.float32([[0,0],[500,0],[0,400],[500,400]])
# ---> 10 for val in pt1:
#      11     cv2.circle(paper,(val[0],val[1]),5,(0,255,0),-1)
#      12 M = cv2.getPerspectiveTransform(pt1,pts2)
#
# NameError: name 'pt1' is not defined
